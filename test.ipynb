# %%
import pandas as pd

# 创建一个示例DataFrame
data = {'category_column': ['A', 'B', 'A', 'C', 'B', 'A']}
df = pd.DataFrame(data)
print(df.shape)
# 使用pd.factorize()函数获取类别编码，并替换原来的类别列
df['category_column_encoded'], unique_categories = pd.factorize(df['category_column'])

# unique_categories包含了原始类别的唯一值
print("唯一类别：", unique_categories)

# 打印替换后的DataFrame
print("替换后的DataFrame：")
print(df)
print(list(unique_categories))
# Out:
# (6, 1)
# 唯一类别： Index(['A', 'B', 'C'], dtype='object')
# 替换后的DataFrame：
#   category_column  category_column_encoded
# 0               A                        0
# 1               B                        1
# 2               A                        0
# 3               C                        2
# 4               B                        1
# 5               A                        0
# ['A', 'B', 'C']

# %%
import pandas as pd

# 创建一个示例的DataFrame
data = {'Category': ['A', 'B', 'A', 'C', 'B', 'A']}
df = pd.DataFrame(data)

# 使用pd.factorize()来将类别编码为整数
df['Category_encoded'], categories = pd.factorize(df['Category'])

# 打印编码后的DataFrame
print("Encoded DataFrame:")
print(df)

# 使用映射将整数还原为类别
df['Category_decoded'] = pd.Series(categories).iloc[df['Category_encoded']].values

# 打印还原后的DataFrame
print("\nDecoded DataFrame:")
print(df)
# Out:
# Encoded DataFrame:
#   Category  Category_encoded
# 0        A                 0
# 1        B                 1
# 2        A                 0
# 3        C                 2
# 4        B                 1
# 5        A                 0
#
# Decoded DataFrame:
#   Category  Category_encoded Category_decoded
# 0        A                 0                A
# 1        B                 1                B
# 2        A                 0                A
# 3        C                 2                C
# 4        B                 1                B
# 5        A                 0                A

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# 创建一个示例的DataFrame
data = {'Category1': ['A', 'B', 'A', 'C', 'B', 'A'],
        'Category2': ['X', 'Y', 'Z', 'X', 'Y', 'Z']}
df = pd.DataFrame(data)

# 对类别列进行整数编码
df['Category1_encoded'], _ = pd.factorize(df['Category1'])
df['Category2_encoded'], _ = pd.factorize(df['Category2'])

# 创建一个热力图
heatmap_data = pd.crosstab(df['Category1_encoded'], df['Category2_encoded'])

# 绘制热力图
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm',
            xticklabels=df['Category2'].unique(),
            yticklabels=df['Category1'].unique())

plt.xlabel('Category2')
plt.ylabel('Category1')
plt.title('Heatmap with Categorical Labels')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import pandas as pd

# 示例真实类别和预测类别
y_true = np.array(['A', 'B', 'A', 'C', 'B', 'A'])
y_pred = np.array(['A', 'B', 'B', 'C', 'A', 'C'])

# 计算混淆矩阵
conf_matrix = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))

# 将混淆矩阵转换为DataFrame，以便更容易绘制
conf_df = pd.DataFrame(conf_matrix, index=np.unique(y_true), columns=np.unique(y_true))

# 绘制混淆矩阵热力图
plt.figure(figsize=(6, 6))
sns.heatmap(conf_df, annot=True, cmap='Blues',
            xticklabels=conf_df.columns, yticklabels=conf_df.index)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix with Categorical Labels')
plt.show()
